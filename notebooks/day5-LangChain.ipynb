# %% [markdown]
# # LangChain: Models, Prompts and Output Parsers
#
# ### Outline
# * Direct API calls to OpenAI
# * API calls through LangChain
#     * Prompts
#     * Models
#     * Output parsers
#
# ## Get your OpenAI API Key

# %%
# !pip install python-dotenv
# !pip install openai
# Out:
# Requirement already satisfied: python-dotenv in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (1.2.2)
# WARNING: Cache entry deserialization failed, entry ignored
# Requirement already satisfied: openai in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (2.44.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (4.68.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in D:\Personal Projects\ai-learning\.venv\Lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

client=OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
# account for deprecation of LLM model
import datetime

# Get the current date
current_date=datetime.datetime.now().date()

# Define the date after which the model should be set to "gpt-3.5-turbo"
target_date=datetime.date(2024,6,12)

llm_model=""
# Set the model variable based on the current date
if current_date>target_date:
    llm_model="gpt-3.5-turbo"
else:
    llm_model="gpt-3.5-turbo-0301"

# %%
def get_completion(prompt,model=llm_model):
    messages=[{"role":"user","content":prompt}]
    response=client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %%
get_completion("What is 1+2?")
# Out:
# '1 + 2 = 3'

# %%
customer_email="""
Arrr, I be fuming that me blender lid
flew off and splattered me kitchen walls
with smoothie! And to make matters worse,
the warranty don't cover the cost of
cleaning up me kitchen. I need yer help
right now, matey! 
"""

# %%
style="""
American English in a calm and respectful tone
"""

# %%
prompt=f""" Translate the text that is delimited by triple backticks \
into a {style}. text:```{customer_email}```
""" 

print(prompt)
# Out:
#  Translate the text that is delimited by triple backticks into a
# American English in a calm and respectful tone
# . text:```
# Arrr, I be fuming that me blender lid
# flew off and splattered me kitchen walls
# with smoothie! And to make matters worse,
# the warranty don't cover the cost of
# cleaning up me kitchen. I need yer help
# right now, matey!
# ```

# %%
response=get_completion(prompt)

# %%
response
# Out:
# "I am frustrated that my blender lid flew off and splattered my kitchen walls with smoothie! To make matters worse, the warranty doesn't cover the cost of cleaning up my kitchen. I need your help right now, friend."
