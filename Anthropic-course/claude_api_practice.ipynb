# %%
# !pip install anthropic
# Out:
# ...
#   Using cached anthropic-0.116.0-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# ...
# Using cached anthropic-0.116.0-py3-none-any.whl (956 kB)
# Using cached docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# ...
#
#    ---------------------------------------- 0/2 [docstring-parser]
#    ---------------------------------------- 0/2 [docstring-parser]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
#    -------------------- ------------------- 1/2 [anthropic]
# ...

# %%
from dotenv import load_dotenv, find_dotenv
from anthropic import Anthropic

load_dotenv(find_dotenv())
client=Anthropic()
model="claude-sonnet-4-6"

# %%
message=client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {"role":"user","content":"What is Quantum computing? Answer in 1 sentence"}
        ]
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 message=client.messages.create(
#       2     model=model,
#       3     max_tokens=1000,
#       4     messages=[
#
# File d:\Personal Projects\ai-learning\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# ...

# %%
message

# Ouput: This will return the output as follows:
# Message(id='<msg ID>',content=[TextBlock(citations=None,text='<answer to the prompt>',type='text')],model='claude-3-7-sonnet-20250219',role='assistant',stop_reason='end-turn',stop_sequence=None,type='message',usage=Usage(cache_creation_input_tokens=0,cache_read_input_tokens=0,input_tokens=16,output_tokens=47))

# To print the content generated by the assistant, we have guve the following command:
message.content[0].text
# Out:
#   Cell In[7], line 2
#     Ouput: This will return the output as follows:
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Multi-turn Conversations

# %%
def add_user_message(messages,text):
    messages.append(
        {"role":"user","content":text}
        )
    
def add_assistant_message(messages,text):
    messages.append(
        {"role":"assistant","content":text}
    )

messages=[]

def get_completion(messages,system=None):
    params={
        "model":model,
        "max_tokens":1000,
        "messages":messages,
    }

    if system:
        params["system"]=system

    response=client.message.create(**params)
    return response.content[0].text

while True:
    SYSTEM="""You are a helpful assistant"""
    prompt=input("You:")
    add_user_message(messages,prompt)
    answer=get_completion(messages,SYSTEM)
    print("Assistant:",answer)
    add_assistant_message(messages,answer)
